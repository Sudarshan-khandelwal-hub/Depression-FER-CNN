# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")
import matplotlib.pyplot as plt
# %matplotlib inline

import datetime
import os
import cv2

import tensorflow as tf
from tensorflow.keras.optimizers import Adam, RMSprop, SGD

from keras import regularizers
from keras.layers import Conv2D, Dense, BatchNormalization, Activation, Dropout, MaxPooling2D, Flatten
from keras.callbacks import ModelCheckpoint, CSVLogger, TensorBoard, EarlyStopping, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.vis_utils import plot_model

from sklearn.metrics import classification_report, confusion_matrix

main_accent_colour = "#b366ff"
dim_colour="darkgrey"
main_palette = ["#FBE5C0", "#DD9A30", "#F88379", "#FF6FC2", "purple", "#D086F6", "#B0D2C2", "#4C5D70", "#6FA2CE", "#382D24", "#3ACF3A", "#7D7D00"]

# %%
train_dir =r"C:\\Users\\sudar\\OneDrive\\Desktop\\Final_year\\train"
test_dir = r"C:\\Users\\sudar\\OneDrive\\Desktop\\Final_year\\test"

row = 48
col = 48
classes = len(os.listdir(r"C:\\Users\\sudar\\OneDrive\\Desktop\\Final_year\\train"))

# %%
print("Train Set :")

train_count = []
for folder in os.listdir(train_dir) :
    print(folder, "folder contains\t\t\t", len(os.listdir(train_dir+"\\"+folder)), "image")
    train_count.append(len(os.listdir(train_dir+"\\"+folder)))
    
print()

test_count = []
print("Test Set :")
for folder in os.listdir(test_dir) :
    print(folder, "folder contains\t\t", len(os.listdir(test_dir+"\\"+folder)), "images")
    test_count.append(len(os.listdir(test_dir+"\\"+folder)))
# Out:
# Train Set :
# angry folder contains			 3995 image
# disgust folder contains			 436 image
# fear folder contains			 4097 image
# happy folder contains			 7215 image
# neutral folder contains			 4965 image
# sad folder contains			 4830 image
# surprise folder contains			 3171 image
#
# Test Set :
# angry folder contains		 958 images
# disgust folder contains		 111 images
# fear folder contains		 1024 images
# happy folder contains		 1774 images
# neutral folder contains		 1233 images
# sad folder contains		 1247 images
# surprise folder contains		 831 images

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

training_set = train_datagen.flow_from_directory(train_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(test_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
training_set.class_indices
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
classnames = ["angry", "disgust", "fear", "happy", "neutral", "sad", "surprise"] # These classes should be folder names

# %%
def get_model(input_size, classes=7):
    
    model = tf.keras.models.Sequential()   

    model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape =input_size))
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(2, 2))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Conv2D(256, kernel_size=(3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(classes, activation='softmax'))

    model.compile(optimizer=Adam(learning_rate=0.0001), 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])
    return model

# %%
fernet = get_model((row,col,1), classes)

# %%
chk_path = 'model.h5'
log_dir = "checkpoint/logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             moniter='val_accuracy')

earlystop = EarlyStopping(monitor='val_accuracy', 
                          min_delta=0, 
                          patience=3, 
                          verbose=1, 
                          restore_best_weights=True)
                        
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', 
                              factor=0.2, 
                              patience=6, 
                              verbose=1, 
                              min_delta=0.0001)


tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
csv_logger = CSVLogger('training.log')

callbacks = [checkpoint, reduce_lr, csv_logger]

# %%
steps_per_epoch = training_set.n // training_set.batch_size
validation_steps = test_set.n // test_set.batch_size
hist = fernet.fit(x=training_set,
                  validation_data=test_set,
                  epochs=60,
                  callbacks=callbacks,
                  steps_per_epoch=steps_per_epoch,
                  validation_steps=validation_steps)
# Out:
# Epoch 1/60
# 448/448 [==============================] - ETA: 0s - loss: 4.2854 - accuracy: 0.2939
# Epoch 1: val_loss improved from inf to 10.35652, saving model to model.h5
# 448/448 [==============================] - 269s 597ms/step - loss: 4.2854 - accuracy: 0.2939 - val_loss: 10.3565 - val_accuracy: 0.0487 - lr: 1.0000e-04
# Epoch 2/60
# 448/448 [==============================] - ETA: 0s - loss: 3.4769 - accuracy: 0.3565
# Epoch 2: val_loss improved from 10.35652 to 3.07993, saving model to model.h5
# 448/448 [==============================] - 37s 82ms/step - loss: 3.4769 - accuracy: 0.3565 - val_loss: 3.0799 - val_accuracy: 0.4203 - lr: 1.0000e-04
# Epoch 3/60
# 448/448 [==============================] - ETA: 0s - loss: 2.9473 - accuracy: 0.3968
# Epoch 3: val_loss improved from 3.07993 to 2.66529, saving model to model.h5
# 448/448 [==============================] - 37s 82ms/step - loss: 2.9473 - accuracy: 0.3968 - val_loss: 2.6653 - val_accuracy: 0.4213 - lr: 1.0000e-04
# Epoch 4/60
# 448/448 [==============================] - ETA: 0s - loss: 2.5415 - accuracy: 0.4187
# Epoch 4: val_loss improved from 2.66529 to 2.26758, saving model to model.h5
# 448/448 [==============================] - 37s 83ms/step - loss: 2.5415 - accuracy: 0.4187 - val_loss: 2.2676 - val_accuracy: 0.4722 - lr: 1.0000e-04
# Epoch 5/60
# 448/448 [==============================] - ETA: 0s - loss: 2.2224 - accuracy: 0.4456
# Epoch 5: val_loss improved from 2.26758 to 2.00013, saving model to model.h5
# 448/448 [==============================] - 37s 82ms/step - loss: 2.2224 - accuracy: 0.4456 - val_loss: 2.0001 - val_accuracy: 0.4859 - lr: 1.0000e-04
# Epoch 6/60
# 448/448 [==============================] - ETA: 0s - loss: 1.9799 - accuracy: 0.4720
# Epoch 6: val_loss improved from 2.00013 to 1.82304, saving model to model.h5
# 448/448 [==============================] - 37s 82ms/step - loss: 1.9799 - accuracy: 0.4720 - val_loss: 1.8230 - val_accuracy: 0.5042 - lr: 1.0000e-04
# Epoch 7/60
# 448/448 [==============================] - ETA: 0s - loss: 1.7953 - accuracy: 0.4884
# Epoch 7: val_loss improved from 1.82304 to 1.64141, saving model to model.h5
# 448/448 [==============================] - 37s 83ms/step - loss: 1.7953 - accuracy: 0.4884 - val_loss: 1.6414 - val_accuracy: 0.5254 - lr: 1.0000e-04
# Epoch 8/60
# 448/448 [==============================] - ETA: 0s - loss: 1.6490 - accuracy: 0.5053
# Epoch 8: val_loss improved from 1.64141 to 1.56459, saving model to model.h5
# 448/448 [==============================] - 37s 83ms/step - loss: 1.6490 - accuracy: 0.5053 - val_loss: 1.5646 - val_accuracy: 0.5194 - lr: 1.0000e-04
# Epoch 9/60
# 448/448 [==============================] - ETA: 0s - loss: 1.5305 - accuracy: 0.5242
# Epoch 9: val_loss improved from 1.56459 to 1.43663, saving model to model.h5
# 448/448 [==============================] - 37s 83ms/step - loss: 1.5305 - accuracy: 0.5242 - val_loss: 1.4366 - val_accuracy: 0.5453 - lr: 1.0000e-04
# Epoch 10/60
# 448/448 [==============================] - ETA: 0s - loss: 1.4465 - accuracy: 0.5408
# Epoch 10: val_loss improved from 1.43663 to 1.33484, saving model to model.h5
# 448/448 [==============================] - 37s 83ms/step - loss: 1.4465 - accuracy: 0.5408 - val_loss: 1.3348 - val_accuracy: 0.5661 - lr: 1.0000e-04
# Epoch 11/60
# 448/448 [==============================] - ETA: 0s - loss: 1.3620 - accuracy: 0.5573
# Epoch 11: val_loss improved from 1.33484 to 1.29119, saving model to model.h5
# 448/448 [==============================] - 38s 84ms/step - loss: 1.3620 - accuracy: 0.5573 - val_loss: 1.2912 - val_accuracy: 0.5766 - lr: 1.0000e-04
# Epoch 12/60
# 448/448 [==============================] - ETA: 0s - loss: 1.2986 - accuracy: 0.5753
# Epoch 12: val_loss improved from 1.29119 to 1.25217, saving model to model.h5
# 448/448 [==============================] - 37s 83ms/step - loss: 1.2986 - accuracy: 0.5753 - val_loss: 1.2522 - val_accuracy: 0.5914 - lr: 1.0000e-04
# Epoch 13/60
# 448/448 [==============================] - ETA: 0s - loss: 1.2416 - accuracy: 0.5882
# Epoch 13: val_loss improved from 1.25217 to 1.21704, saving model to model.h5
# 448/448 [==============================] - 37s 83ms/step - loss: 1.2416 - accuracy: 0.5882 - val_loss: 1.2170 - val_accuracy: 0.5940 - lr: 1.0000e-04
# Epoch 14/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1990 - accuracy: 0.5987
# Epoch 14: val_loss improved from 1.21704 to 1.18168, saving model to model.h5
# 448/448 [==============================] - 37s 83ms/step - loss: 1.1990 - accuracy: 0.5987 - val_loss: 1.1817 - val_accuracy: 0.5988 - lr: 1.0000e-04
# Epoch 15/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1490 - accuracy: 0.6158
# Epoch 15: val_loss improved from 1.18168 to 1.17329, saving model to model.h5
# 448/448 [==============================] - 37s 83ms/step - loss: 1.1490 - accuracy: 0.6158 - val_loss: 1.1733 - val_accuracy: 0.6044 - lr: 1.0000e-04
# Epoch 16/60
# 448/448 [==============================] - ETA: 0s - loss: 1.1095 - accuracy: 0.6303
# Epoch 16: val_loss improved from 1.17329 to 1.17205, saving model to model.h5
# 448/448 [==============================] - 37s 83ms/step - loss: 1.1095 - accuracy: 0.6303 - val_loss: 1.1721 - val_accuracy: 0.6133 - lr: 1.0000e-04
# Epoch 17/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0695 - accuracy: 0.6448
# Epoch 17: val_loss improved from 1.17205 to 1.14533, saving model to model.h5
# 448/448 [==============================] - 37s 83ms/step - loss: 1.0695 - accuracy: 0.6448 - val_loss: 1.1453 - val_accuracy: 0.6127 - lr: 1.0000e-04
# Epoch 18/60
# 448/448 [==============================] - ETA: 0s - loss: 1.0320 - accuracy: 0.6600
# Epoch 18: val_loss did not improve from 1.14533
# 448/448 [==============================] - 36s 81ms/step - loss: 1.0320 - accuracy: 0.6600 - val_loss: 1.1627 - val_accuracy: 0.6222 - lr: 1.0000e-04
# Epoch 19/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9976 - accuracy: 0.6725
# Epoch 19: val_loss improved from 1.14533 to 1.12580, saving model to model.h5
# 448/448 [==============================] - 38s 84ms/step - loss: 0.9976 - accuracy: 0.6725 - val_loss: 1.1258 - val_accuracy: 0.6314 - lr: 1.0000e-04
# Epoch 20/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9642 - accuracy: 0.6798
# Epoch 20: val_loss did not improve from 1.12580
# 448/448 [==============================] - 37s 81ms/step - loss: 0.9642 - accuracy: 0.6798 - val_loss: 1.1285 - val_accuracy: 0.6221 - lr: 1.0000e-04
# Epoch 21/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9300 - accuracy: 0.6946
# Epoch 21: val_loss improved from 1.12580 to 1.12349, saving model to model.h5
# 448/448 [==============================] - 37s 83ms/step - loss: 0.9300 - accuracy: 0.6946 - val_loss: 1.1235 - val_accuracy: 0.6275 - lr: 1.0000e-04
# Epoch 22/60
# 448/448 [==============================] - ETA: 0s - loss: 0.9036 - accuracy: 0.7041
# Epoch 22: val_loss did not improve from 1.12349
# 448/448 [==============================] - 37s 82ms/step - loss: 0.9036 - accuracy: 0.7041 - val_loss: 1.1426 - val_accuracy: 0.6304 - lr: 1.0000e-04
# Epoch 23/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8798 - accuracy: 0.7136
# Epoch 23: val_loss did not improve from 1.12349
# 448/448 [==============================] - 37s 81ms/step - loss: 0.8798 - accuracy: 0.7136 - val_loss: 1.1397 - val_accuracy: 0.6327 - lr: 1.0000e-04
# Epoch 24/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8469 - accuracy: 0.7261
# Epoch 24: val_loss did not improve from 1.12349
# 448/448 [==============================] - 36s 81ms/step - loss: 0.8469 - accuracy: 0.7261 - val_loss: 1.1472 - val_accuracy: 0.6242 - lr: 1.0000e-04
# Epoch 25/60
# 448/448 [==============================] - ETA: 0s - loss: 0.8134 - accuracy: 0.7371
# Epoch 25: val_loss did not improve from 1.12349
# 448/448 [==============================] - 37s 81ms/step - loss: 0.8134 - accuracy: 0.7371 - val_loss: 1.1470 - val_accuracy: 0.6304 - lr: 1.0000e-04
# Epoch 26/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7907 - accuracy: 0.7465
# Epoch 26: val_loss improved from 1.12349 to 1.12020, saving model to model.h5
# 448/448 [==============================] - 38s 84ms/step - loss: 0.7907 - accuracy: 0.7465 - val_loss: 1.1202 - val_accuracy: 0.6401 - lr: 1.0000e-04
# Epoch 27/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7721 - accuracy: 0.7548
# Epoch 27: val_loss did not improve from 1.12020
# 448/448 [==============================] - 36s 81ms/step - loss: 0.7721 - accuracy: 0.7548 - val_loss: 1.1304 - val_accuracy: 0.6426 - lr: 1.0000e-04
# Epoch 28/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7473 - accuracy: 0.7639
# Epoch 28: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 81ms/step - loss: 0.7473 - accuracy: 0.7639 - val_loss: 1.1417 - val_accuracy: 0.6369 - lr: 1.0000e-04
# Epoch 29/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7233 - accuracy: 0.7727
# Epoch 29: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.7233 - accuracy: 0.7727 - val_loss: 1.1801 - val_accuracy: 0.6384 - lr: 1.0000e-04
# Epoch 30/60
# 448/448 [==============================] - ETA: 0s - loss: 0.7034 - accuracy: 0.7785
# Epoch 30: val_loss did not improve from 1.12020
# 448/448 [==============================] - 36s 81ms/step - loss: 0.7034 - accuracy: 0.7785 - val_loss: 1.1925 - val_accuracy: 0.6417 - lr: 1.0000e-04
# Epoch 31/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6837 - accuracy: 0.7878
# Epoch 31: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 81ms/step - loss: 0.6837 - accuracy: 0.7878 - val_loss: 1.1675 - val_accuracy: 0.6511 - lr: 1.0000e-04
# Epoch 32/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6663 - accuracy: 0.7910
# Epoch 32: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.6663 - accuracy: 0.7910 - val_loss: 1.1414 - val_accuracy: 0.6497 - lr: 1.0000e-04
# Epoch 33/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6497 - accuracy: 0.8006
# Epoch 33: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.6497 - accuracy: 0.8006 - val_loss: 1.1363 - val_accuracy: 0.6511 - lr: 1.0000e-04
# Epoch 34/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6297 - accuracy: 0.8066
# Epoch 34: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 81ms/step - loss: 0.6297 - accuracy: 0.8066 - val_loss: 1.1559 - val_accuracy: 0.6503 - lr: 1.0000e-04
# Epoch 35/60
# 448/448 [==============================] - ETA: 0s - loss: 0.6180 - accuracy: 0.8118
# Epoch 35: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 81ms/step - loss: 0.6180 - accuracy: 0.8118 - val_loss: 1.3007 - val_accuracy: 0.6246 - lr: 1.0000e-04
# Epoch 36/60
# 448/448 [==============================] - ETA: 0s - loss: 0.5956 - accuracy: 0.8216
# Epoch 36: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.5956 - accuracy: 0.8216 - val_loss: 1.2047 - val_accuracy: 0.6399 - lr: 1.0000e-04
# Epoch 37/60
# 448/448 [==============================] - ETA: 0s - loss: 0.5786 - accuracy: 0.8253
# Epoch 37: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.5786 - accuracy: 0.8253 - val_loss: 1.1996 - val_accuracy: 0.6568 - lr: 1.0000e-04
# Epoch 38/60
# 448/448 [==============================] - ETA: 0s - loss: 0.5652 - accuracy: 0.8304
# Epoch 38: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 81ms/step - loss: 0.5652 - accuracy: 0.8304 - val_loss: 1.2765 - val_accuracy: 0.6405 - lr: 1.0000e-04
# Epoch 39/60
# 448/448 [==============================] - ETA: 0s - loss: 0.5633 - accuracy: 0.8290
# Epoch 39: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.5633 - accuracy: 0.8290 - val_loss: 1.1654 - val_accuracy: 0.6537 - lr: 1.0000e-04
# Epoch 40/60
# 448/448 [==============================] - ETA: 0s - loss: 0.5459 - accuracy: 0.8365
# Epoch 40: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.5459 - accuracy: 0.8365 - val_loss: 1.2502 - val_accuracy: 0.6486 - lr: 1.0000e-04
# Epoch 41/60
# 448/448 [==============================] - ETA: 0s - loss: 0.5339 - accuracy: 0.8405
# Epoch 41: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.5339 - accuracy: 0.8405 - val_loss: 1.2278 - val_accuracy: 0.6501 - lr: 1.0000e-04
# Epoch 42/60
# 448/448 [==============================] - ETA: 0s - loss: 0.5225 - accuracy: 0.8447
# Epoch 42: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 81ms/step - loss: 0.5225 - accuracy: 0.8447 - val_loss: 1.2661 - val_accuracy: 0.6482 - lr: 1.0000e-04
# Epoch 43/60
# 448/448 [==============================] - ETA: 0s - loss: 0.5123 - accuracy: 0.8482
# Epoch 43: val_loss did not improve from 1.12020
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 448/448 [==============================] - 37s 83ms/step - loss: 0.5123 - accuracy: 0.8482 - val_loss: 1.2779 - val_accuracy: 0.6523 - lr: 1.0000e-04
# Epoch 44/60
# 448/448 [==============================] - ETA: 0s - loss: 0.4617 - accuracy: 0.8678
# Epoch 44: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.4617 - accuracy: 0.8678 - val_loss: 1.2496 - val_accuracy: 0.6604 - lr: 2.0000e-05
# Epoch 45/60
# 448/448 [==============================] - ETA: 0s - loss: 0.4275 - accuracy: 0.8797
# Epoch 45: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.4275 - accuracy: 0.8797 - val_loss: 1.2511 - val_accuracy: 0.6643 - lr: 2.0000e-05
# Epoch 46/60
# 448/448 [==============================] - ETA: 0s - loss: 0.4271 - accuracy: 0.8788
# Epoch 46: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.4271 - accuracy: 0.8788 - val_loss: 1.2413 - val_accuracy: 0.6631 - lr: 2.0000e-05
# Epoch 47/60
# 448/448 [==============================] - ETA: 0s - loss: 0.4118 - accuracy: 0.8856
# Epoch 47: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 81ms/step - loss: 0.4118 - accuracy: 0.8856 - val_loss: 1.2640 - val_accuracy: 0.6648 - lr: 2.0000e-05
# Epoch 48/60
# 448/448 [==============================] - ETA: 0s - loss: 0.3976 - accuracy: 0.8894
# Epoch 48: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 81ms/step - loss: 0.3976 - accuracy: 0.8894 - val_loss: 1.2611 - val_accuracy: 0.6656 - lr: 2.0000e-05
# Epoch 49/60
# 448/448 [==============================] - ETA: 0s - loss: 0.3939 - accuracy: 0.8907
# Epoch 49: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.3939 - accuracy: 0.8907 - val_loss: 1.2657 - val_accuracy: 0.6611 - lr: 2.0000e-05
# Epoch 50/60
# 448/448 [==============================] - ETA: 0s - loss: 0.3886 - accuracy: 0.8926
# Epoch 50: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.3886 - accuracy: 0.8926 - val_loss: 1.2812 - val_accuracy: 0.6648 - lr: 2.0000e-05
# Epoch 51/60
# 448/448 [==============================] - ETA: 0s - loss: 0.3801 - accuracy: 0.8946
# Epoch 51: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.3801 - accuracy: 0.8946 - val_loss: 1.2474 - val_accuracy: 0.6695 - lr: 2.0000e-05
# Epoch 52/60
# 448/448 [==============================] - ETA: 0s - loss: 0.3751 - accuracy: 0.8965
# Epoch 52: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.3751 - accuracy: 0.8965 - val_loss: 1.3103 - val_accuracy: 0.6674 - lr: 2.0000e-05
# Epoch 53/60
# 448/448 [==============================] - ETA: 0s - loss: 0.3747 - accuracy: 0.8975
# Epoch 53: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 83ms/step - loss: 0.3747 - accuracy: 0.8975 - val_loss: 1.2680 - val_accuracy: 0.6664 - lr: 2.0000e-05
# Epoch 54/60
# 448/448 [==============================] - ETA: 0s - loss: 0.3675 - accuracy: 0.8982
# Epoch 54: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.3675 - accuracy: 0.8982 - val_loss: 1.2837 - val_accuracy: 0.6643 - lr: 2.0000e-05
# Epoch 55/60
# 448/448 [==============================] - ETA: 0s - loss: 0.3532 - accuracy: 0.9026
# Epoch 55: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.3532 - accuracy: 0.9026 - val_loss: 1.3217 - val_accuracy: 0.6670 - lr: 2.0000e-05
# Epoch 56/60
# 448/448 [==============================] - ETA: 0s - loss: 0.3558 - accuracy: 0.9033
# Epoch 56: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.3558 - accuracy: 0.9033 - val_loss: 1.2867 - val_accuracy: 0.6671 - lr: 2.0000e-05
# Epoch 57/60
# 448/448 [==============================] - ETA: 0s - loss: 0.3466 - accuracy: 0.9059
# Epoch 57: val_loss did not improve from 1.12020
# 448/448 [==============================] - 36s 81ms/step - loss: 0.3466 - accuracy: 0.9059 - val_loss: 1.3022 - val_accuracy: 0.6696 - lr: 2.0000e-05
# Epoch 58/60
# 448/448 [==============================] - ETA: 0s - loss: 0.3512 - accuracy: 0.9013
# Epoch 58: val_loss did not improve from 1.12020
# 448/448 [==============================] - 36s 81ms/step - loss: 0.3512 - accuracy: 0.9013 - val_loss: 1.3031 - val_accuracy: 0.6703 - lr: 2.0000e-05
# Epoch 59/60
# 448/448 [==============================] - ETA: 0s - loss: 0.3398 - accuracy: 0.9081
# Epoch 59: val_loss did not improve from 1.12020
# 448/448 [==============================] - 36s 81ms/step - loss: 0.3398 - accuracy: 0.9081 - val_loss: 1.2807 - val_accuracy: 0.6685 - lr: 2.0000e-05
# Epoch 60/60
# 448/448 [==============================] - ETA: 0s - loss: 0.3312 - accuracy: 0.9104
# Epoch 60: val_loss did not improve from 1.12020
# 448/448 [==============================] - 37s 82ms/step - loss: 0.3312 - accuracy: 0.9104 - val_loss: 1.3041 - val_accuracy: 0.6709 - lr: 2.0000e-05

# %%
fernet.save("Realtime_CNN_Model.h5")

# %% [markdown]
# ### Representing model accuracy graphically

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

# %% [markdown]
# ### Representing model loss graphically

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

# %%
model = tf.keras.models.load_model('model.h5')

# %% [markdown]
# ### Getting Final Train Accuracy and Validation Accuracy

# %%
train_loss, train_accu = model.evaluate(training_set)
test_loss, test_accu = model.evaluate(test_set) 
print("Final train accuracy = {:.2f} , Validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 449/449 [==============================] - 19s 42ms/step - loss: 0.5857 - accuracy: 0.8388
# 113/113 [==============================] - 3s 23ms/step - loss: 1.1194 - accuracy: 0.6403
# Final train accuracy = 83.88 , Validation accuracy = 64.03

# %% [markdown]
# ### Confusion Matrix

# %%
y_pred = model.predict(training_set)
y_pred = np.argmax(y_pred, axis=1)
class_labels = test_set.class_indices
class_labels = {v:k for k,v in class_labels.items()}

cm_train = confusion_matrix(training_set.classes, y_pred)
print('Confusion Matrix')
print(cm_train)
# Out:
# 449/449 [==============================] - 18s 40ms/step
# Confusion Matrix
# [[ 552   50  473 1085  740  665  430]
#  [  60    4   60   98   86   79   49]
#  [ 560   54  493 1094  804  630  462]
#  [1000   94  929 1933 1333 1132  794]
#  [ 642   51  596 1369  981  769  557]
#  [ 637   60  578 1328  951  779  497]
#  [ 389   34  433  877  572  504  362]]

# %%
print('Classification Report\n')
target_names = list(class_labels.values())
print(classification_report(training_set.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#
#               precision    recall  f1-score   support
#
#        angry       0.14      0.14      0.14      3995
#      disgust       0.01      0.01      0.01       436
#         fear       0.14      0.12      0.13      4097
#        happy       0.25      0.27      0.26      7215
#      neutral       0.18      0.20      0.19      4965
#          sad       0.17      0.16      0.17      4830
#     surprise       0.11      0.11      0.11      3171
#
#     accuracy                           0.18     28709
#    macro avg       0.14      0.14      0.14     28709
# weighted avg       0.17      0.18      0.18     28709

# %%
image = cv2.imread(r"C:\Users\sudar\OneDrive\Desktop\Real-Time Image Detection\I1.jpg", cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(image,cmap='gray')
plt.show()

# %%
image = cv2.resize(image,(48,48))
img=np.array(image)
img=img.reshape(1,48,48,1)
predict_x=model.predict(img) 
result=np.argmax(predict_x,axis=1)
classnames[result[0]]
# Out:
# 1/1 [==============================] - 0s 143ms/step
# 'neutral'

# %%
# !python create_data.py

# %%
Data_dir = r"C:\\Users\\sudar\\OneDrive\\Desktop\\Face\\"
import glob

# %%
ext = ['png', 'jpeg', 'jpg']    # Add image formats here
files = []
[files.extend(glob.glob(Data_dir + '*.' + e)) for e in ext]
images = [cv2.imread(file, cv2.IMREAD_GRAYSCALE) for file in files]
print(len(images))
# Out:
# 99

# %%
img_out = []
for i in range(len(images)):
    img_out.append(images[i])

# %%
len(img_out)
pred_out = []

# %%
def img_size(image):
    image = cv2.resize(image,(48,48))
    img=np.array(image)
    img=img.reshape(1,48,48,1)
    pred_out.append(model.predict(img))

# %%
for i in range(len(img_out)):
    img_size(img_out[i])
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step

# %%
pred_scores = []
for i in range(len(pred_out)):
    pred_scores.append(np.argmax(pred_out[i],axis=1))

# %%
sent_out = []
for i in range(len(pred_scores)):
    sent_out.append(classnames[pred_scores[i][0]])

# %%
# print(sent_out)
print(len(sent_out))
print(sent_out)
# Out:
# 99
# ['angry', 'angry', 'angry', 'angry', 'angry', 'angry', 'angry', 'angry', 'angry', 'angry', 'angry', 'fear', 'happy', 'happy', 'happy', 'angry', 'angry', 'angry', 'angry', 'angry', 'angry', 'angry', 'fear', 'fear', 'fear', 'fear', 'fear', 'fear', 'happy', 'happy', 'happy', 'fear', 'fear', 'fear', 'fear', 'fear', 'fear', 'fear', 'fear', 'fear', 'fear', 'fear', 'fear', 'fear', 'angry', 'fear', 'fear', 'fear', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'angry', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'angry', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'angry', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'angry', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy', 'happy']

# %%
dc = 0  # negative emotion count
hc = 0  # positive emotion count
suc = 0 # surprise count

# %%
for i in range(len(sent_out)):
  if(sent_out[i] == 'angry' or sent_out[i] == 'disgust' or sent_out[i] == 'sad' or sent_out[i] == 'fear'):
      dc += 1
  elif (sent_out[i] == 'happy' or sent_out[i] == 'neutral'):
      hc += 1
  elif (sent_out[i] == 'surprise'):
      suc += 1
print("Sad Emotions : ", dc)
print("Happy Emotions : ", hc)
print("Surprise Emotions : ", suc)
# Out:
# Sad Emotions :  46
# Happy Emotions :  53
# Surprise Emotions :  0

# %%
pos_rate = round((hc / (dc + hc + suc)), 2) * 100
neg_rate = round((dc / (dc + hc + suc)), 2) * 100

# %%
print("\nNegative emotions : ", neg_rate, "%")
print("\nPositive emotions : ", pos_rate, "%")
# Out:
# Negative emotions :  23.0 %
#
# Positive emotions :  77.0 %

# %%
if (neg_rate <= 30.0):
  if (neg_rate <= 5.0):
    print("just chill and relax ")
  else:
    print("***   MILD DEPRESSION  ***")

  if (neg_rate <= 10.0):
    print("\nDepression Scale Detected : ", round(neg_rate) / 10,"\n")
    print("My Response :\tEverything is a-okay! There's absolutely nothing wrong 😁😁\n\t\tYou're probably cuddling a fluffy kitten right now")
  
  elif (neg_rate > 10.0 and neg_rate <= 20.0):
    print("\nDepression Scale Detected : ", round(neg_rate) / 10,"\n")
    print("My Response :\tYou are a bit frustated and disappointed\n\t\tBut you're easily distracted and cheered with little effort 😁😁")
  
  elif (neg_rate > 20.0 and neg_rate <= 30.0):
    print("\nDepression Scale Detected : ", round(neg_rate) / 10,"\n")
    print("My Response :\tThings are bothering you but you're coping up\n\t\tYou might be over tired and hungry\n\t\tThe emotional equivalent of a headache 😁😁")
  
elif (neg_rate > 30.0 and neg_rate <= 60.0):
  print("***   MODERATE DEPRESSION  ***")
  
  if (neg_rate > 30.0 and neg_rate <= 40.0):
    print("\nDepression Scale Detected : ", round(neg_rate) / 10,"\n")
    print("My Response :\tToday is slighly a bad for you.\n\t\tYou still have the skills to get through it, but be gentle with yourself\n\t\tUse self-care strategies 😁😁")

  elif (neg_rate > 40.0 and neg_rate <= 50.0):
    print("\nDepression Scale Detected : ", round(neg_rate) / 10,"\n")
    print("My Response :\tYour mental health is starting to impact your everyday life.\n\t\tEasy things are becoming difficult")
  
  elif (neg_rate > 50.0 and neg_rate <= 60.0):
    print("\nDepression Scale Detected : ", round(neg_rate) / 10,"\n")
    print("My Response :\tYou are not able to do things the way usually you do them due to your mental health.\n\t\tImpulsive and compulsive thoughts might be difficult to cope with")
  
elif (neg_rate > 60.0 and neg_rate <= 100.0):
  print("***   SEVERE DEPRESSION  ***")
  if (neg_rate > 60.0 and neg_rate <= 70.0):
    print("\nDepression Scale Detected : ", round(neg_rate) / 10,"\n")
    print("My Response :\tYou are loosing interests in the activities that were used to be enjoyable.\n\t\tYou should definitely seek help\n\t\tThis is becoming serious ☹☹")
  
  elif (neg_rate > 70.0 and neg_rate <= 80.0):
    print("\nDepression Scale Detected : ", round(neg_rate) / 10,"\n")
    print("My Response :\tYou can't ignore your struggles now, It's HIGH time!.\n\t\tYou may have issues sleeping, eating, having fun, socializing and work/study\n\t\tYour mental health is affecting almost all parts of your life ☹☹")

  elif (neg_rate > 80.0 and neg_rate <= 90.0):
    print("\nDepression Scale Detected : ", round(neg_rate) / 10,"\n")
    print("My Response :\tYou are at a critical point !!!.\n\t\tYou aren't functioning anymore and need urgent help.\n\t\tYou maybe a risk to yourself or others if left untreated ☹☹")

  elif (neg_rate > 90.0 and neg_rate <= 100.0):
    print("\nDepression Scale Detected : ", round(neg_rate) / 10,"\n")
    print("My Response :\tThe worst mental and emotional distress possible.\n\t\tYou can't imagine things getting any better now and you might think it's all over for you (SUICIDE).\n\t\tContact crisis line or get started for the treatment immediately. ☹☹")
# Out:
# ***   MODERATE DEPRESSION  ***
#
# Depression Scale Detected :  4.6
#
# My Response :	Your mental health is starting to impact your everyday life.
# 		Easy things are becoming difficult

# %% [markdown]
# #### Remove files from the directory once done

# %%
dir = 'C:\\Users\\sudar\\OneDrive\\Desktop\\Real-Time Image Detection\\Face_Data'
for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))
